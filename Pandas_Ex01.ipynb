# %%
import pandas as pd

# %%
df = pd.read_csv('pokemon_data.csv')
print(df.head(5))

#df_xlsx = pd.read_excel('pokemon_data.xlsx')
#print(df_xlsx.head(4))

df_txt = pd.read_csv('pokemon_data.txt', delimiter='\t')
print(df_txt.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# ...

# %%
# Read headers
df_txt.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
## Read each column
#print(df['Name'][0:5])

print(df[['Name', 'HP', 'Attack']][0:5])
# Out:
#                     Name  HP  Attack
# 0              Bulbasaur  45      49
# 1                Ivysaur  60      62
# 2               Venusaur  80      82
# 3  VenusaurMega Venusaur  80     100
# 4             Charmander  39      52

# %%
## Read each row
print(df.iloc[1:4])
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
## Read a specific location [R,C]

print(df.iloc[2,1])
# Out:
# Venusaur

# %%
## iterate rows
#for index,row in df.iterrows():
#    print(index, row['Name'])

#df.loc[df['Type 1'] == 'Fire']

# %% [markdown]
# #### Sorting/Describing Data

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
#df.sort_values('Name', ascending=False)

#df.sort_values(['Name', 'Type 1'])

# %% [markdown]
# #### Making changes to the data

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
df = df.drop(columns=['Total'])
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df = pd.read_csv('pokemon_data.csv')

df['Total'] = df.iloc[:, 4:10].sum(axis=1) # Total column added to dataframe

cols = df.columns.tolist() # read a list from dataframe columns 
df = df[cols[0:4] + [cols[-1]] + cols[4:12]] # arranging dataframe columns as you required.

df.head(5)

# modified data can be written to csv
#df.to_csv('modified_pokemon_data.csv', index=False)
#df.to_excel('modified_pokemon_data.xlsx', index=False)
#df.to_csv('modified_pokemon_data.txt', index=False, sep='\t')

# %% [markdown]
# #### Filtering Data

# %%
df
#df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]
#df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Poison')]
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

new_df
#new_df = new_df.reset_index()
new_df.reset_index(drop=True, inplace=True)
new_df
#new_df.to_csv('filtered.csv', index=False)
# Out:
#      #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0    3               Venusaur  Grass  Poison    525   80      82       83
# 1    3  VenusaurMega Venusaur  Grass  Poison    625   80     100      123
# 2   45              Vileplume  Grass  Poison    490   75      80       85
# 3   71             Victreebel  Grass  Poison    490   80     105       65
# 4  591              Amoonguss  Grass  Poison    464  114      85       70
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0      100      100     80           1      False
# 1      122      120     80           1      False
# 2      110       90     50           1      False
# 3      100       70     70           1      False
# 4       85       80     30           5      False

# %%
#df.loc[df['Name'].str.contains('Mega')]
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                   Name    Type 1  Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur     Grass  Poison   45      49       49
# 1      2                Ivysaur     Grass  Poison   60      62       63
# 2      3               Venusaur     Grass  Poison   80      82       83
# 4      4             Charmander      Fire     NaN   39      52       43
# 5      5             Charmeleon      Fire     NaN   58      64       58
# 6      6              Charizard      Fire  Flying   78      84       78
# 9      7               Squirtle     Water     NaN   44      48       65
# 10     8              Wartortle     Water     NaN   59      63       80
# 11     9              Blastoise     Water     NaN   79      83      100
# 13    10               Caterpie       Bug     NaN   45      30       35
# 14    11                Metapod       Bug     NaN   50      20       55
# 15    12             Butterfree       Bug  Flying   60      45       50
# ...

# %%
import re

#regular expressions
#df.loc[df['Type 1'].str.contains('Fire|Grass', regex=True)]

#df.loc[df['Type 1'].str.contains('fire|grass', flags = re.I, regex=True)]

# regular expression column name started with pi
df.loc[df['Name'].str.contains('^pi[a-z]*', flags = re.I, regex=True)]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %% [markdown]
# #### Conditional Changes

# %%
#Changing the dataframe based upon some conditions

df = pd.read_csv('modified_pokemon_data.csv')
#print(df)

# Here I'm changing the 'Generation' and 'Legendary' column value to 'TEST VALUE', if Total column value is > 500
#df.loc[df['Total'] > 500, ['Generation', 'Legendary']] = 'TEST VALUE'
#df

# if Total column > 500, change Generation and Legendary column values
df.loc[df['Total'] > 500, ['Generation', 'Legendary']] = ['Test1', 'Test2']
df
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4      4                 Charmander      Fire     NaN    309   39      52
# 5      5                 Charmeleon      Fire     NaN    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water     NaN    314   44      48
# 10     8                  Wartortle     Water     NaN    405   59      63
# 11     9                  Blastoise     Water     NaN    530   79      83
# ...

# %% [markdown]
# #### Aggregate Statistics Group By
